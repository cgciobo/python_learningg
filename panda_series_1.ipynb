# %% [markdown]
# <a href="https://colab.research.google.com/github/cgciobo/python_learningg/blob/main/panda_series_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
data_dict = {'Geeks':10, 'for':20, 'geeks':30}
ser = pd.Series(data_dict)
print(ser)
# Out:
# Geeks    10
# for      20
# geeks    30
# dtype: int64

# %%
list=[1,2,3,4]
ser1=pd.Series(data=list)
print(ser1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#definești un dicționar Python
data_orient = {'col_1':[3,2,1,0], 'col_2':['a','b','c','d']}
#pd.DataFrame.from_dict(data_orient)
#pd.DataFrame.from_dict(data_orient,orient='index')
pd.DataFrame.from_dict(data_orient,orient='index', columns = ['A','B','C','D'])
# Out:
#        A  B  C  D
# col_1  3  2  1  0
# col_2  a  b  c  d

# %%
# reading data from csv file
# df = pd.read_csv('dataset.csv')
# df = pd.read_csv('dataset.csv', index_col=0)
# print(df)

# ! = spune Colab sa ruleze comanda in terminal
if not os.path.exists('python_learningg'):
  ! git clone https://github.com/cgciobo/python_learningg.git

! ls python_learningg/

print()  # linie goală, pentru vizibilitate

df = pd.read_json('python_learningg/ex1.json')
print(df)
# Out:
# ex1.json  panda_series_1.ipynb	README.md
#
#         apples  oranges
# Ahmad        3        0
# Ali          2        3
# Rashed       0        7
# Hamza        1        2

# %% [markdown]
# <a href="https://colab.research.google.com/github/cgciobo/python_learningg/blob/main/panda_series_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
obj = Series([4, 7, -5, 3])
print(obj)
print(obj.index)
print(obj.values)
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64
# RangeIndex(start=0, stop=4, step=1)
# [ 4  7 -5  3]
